# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Read the whole text.
txtfile = "cnn.txt"  # 剛才下載存的文字檔
pngfile = "cloud.png"  # 剛才下載存的底圖
text = open(txtfile,"r",encoding="utf-8").read()
alice_mask = np.array(Image.open(pngfile))

# Generate a word cloud image
wordcloud = WordCloud(background_color="white", mask=alice_mask, contour_width=10, contour_color='steelblue').generate(text)
# 繪圖
plt.figure()
plt.axis("off")
plt.imshow(wordcloud, interpolation="bilinear")

# plt.imsave(wordcloud, './wordcloud.png')
plt.imsave('./wordcloud.png', wordcloud)
# plt.show()

# %%
plt.axis("off")
plt.imshow(alice_mask)

# %%
# Generate a word cloud image
wordcloud = WordCloud(background_color="white", mask=alice_mask, contour_width=10, contour_color='steelblue').generate(text)

# 繪圖
plt.figure()
plt.axis("off")
plt.imshow(wordcloud, interpolation="bilinear")

# plt.imsave(wordcloud, './wordcloud.png')
plt.imsave('./wordcloud.png', wordcloud)
# plt.show()

# %%
conn.cursor()

# %%
cur = conn.cursor()

# get annual sales rank
sql = "select * from member"
cur.execute(sql)
content = cur.fetchall()

# %%
content
# Out:
# (('yf.jeff.liu@gmail.com', '123', '1', '2'),
#  ('yf.jeff.liu@gmail.com', '123', '1', '123'))

# %%
# 獲取表頭
sql = "SHOW FIELDS FROM member"
cur.execute(sql)
labels = cur.fetchall()
labels = [l[0] for l in labels]

# %%
labels
# Out:
# ['email', 'passwd', 'name', 'studentID']
